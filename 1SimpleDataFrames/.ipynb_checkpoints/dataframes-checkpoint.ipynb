# %%
import pandas as pd

# %%
df = pd.read_csv('./data/weather.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df["day"]
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.day)
# Out:
# pandas.core.series.Series

# %%
df.temperature.max()
# Out:
# 35

# %%
df.temperature.min()
# Out:
# 24

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
# df[['day', 'windspeed']][df.temperature > 28]
df[df.temperature > 28]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[(df['temperature'] > 30) & (df['event'] == 'Rain')]
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 4  1/5/2017           32          4  Rain

# %%
df_day  = df.set_index('day')
df_day
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df_day.loc['1/3/2017']
# df_day.loc[['1/3/2017', '1/4/2017']]
# Out:
# temperature      28
# windspeed         2
# event          Snow
# Name: 1/3/2017, dtype: object

# %%
df_day.set_index('day', inplace=True)

# %%
df_day.sort_values(by=['day'], ascending=False)
# Out:
#           temperature  windspeed  event
# day
# 1/6/2017           31          2  Sunny
# 1/5/2017           32          4   Rain
# 1/4/2017           24          7   Snow
# 1/3/2017           28          2   Snow
# 1/2/2017           35          7  Sunny
# 1/1/2017           32          6   Rain

# %%
# df_xls = pd.read_excel('./data/comments.xlsx', 'Data File')
df_xls = pd.read_excel('./data/comments.xlsx', 'Data File', header=None, skiprows=1, names=['agency', 'role', 'PL', 'CL', 'Life', 'score', 'NPS', 'is_easy', 'comments', 'category'])
df_xls[(df_xls['CL'].notnull()) & (df_xls['PL'].notnull()) & (df_xls['Life'].notnull() & (df_xls['category'].notnull()))]
# Out:
#        agency                                   role              PL  \
# 5     3401876  Customer Service Representative (CSR)  Personal Lines
# 13       2156                              Principal  Personal Lines
# 43      21059                              Principal  Personal Lines
# 45       4377                              Principal  Personal Lines
# 57    3401605                              Principal  Personal Lines
# 62    3401490                               Producer  Personal Lines
# 70    3701147                               Producer  Personal Lines
# 115     22430                               Producer  Personal Lines
# 127      4674                               Producer  Personal Lines
# 137   1001012                               Producer  Personal Lines
# 181      1129  Customer Service Representative (CSR)  Personal Lines
# 210   4101031                              Principal  Personal Lines
# 212   3401718                              Principal  Personal Lines
# ...

# %%
df_xls.to_csv('./data/auto_comments.csv', index=False)

# %%
df_xls.columns
# Out:
# Index(['agency', 'role', 'PL', 'CL', 'Life', 'score', 'NPS', 'is_easy',
#        'comments', 'category'],
#       dtype='object')

# %%
df_xls[df_xls['PL'].isnull()]
# Out:
#        agency                                   role   PL                CL  \
# 11       2085                               Producer  NaN               NaN
# 12       4927                               Producer  NaN  Commercial Lines
# 19      48377  Customer Service Representative (CSR)  NaN  Commercial Lines
# 27       1031                              Principal  NaN  Commercial Lines
# 34    1201001                                  Other  NaN               NaN
# 37      22131  Customer Service Representative (CSR)  NaN  Commercial Lines
# 39        514                               Producer  NaN  Commercial Lines
# 49    3901250                               Producer  NaN               NaN
# 52      22143                              Principal  NaN  Commercial Lines
# 54    1301125                                  Other  NaN  Commercial Lines
# 60      48107                               Producer  NaN  Commercial Lines
# ...
